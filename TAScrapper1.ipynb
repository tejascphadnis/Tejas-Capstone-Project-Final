# %% [markdown]
# # Trip Advisor Scraper

# %%
from bs4 import BeautifulSoup
from lxml import html
import requests
import pandas as pd
import re

# %%
#base_url = "https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-Universal_Studios_Singapore-Sentosa_Island.html"
#base_url = "https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or2000-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS"
base_url = "https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4000-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS"

#base_url = "https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or1000-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS"
#base_url = "https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or2000-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS"
#base_url = "https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or3000-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS"
#base_url = "https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4000-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS"

# %%
def get_review_details(review_str):
    regex = re.compile(r"<a href=\"(.*)\"\sid=\"(.*)\"\sonclick")
    m1 = regex.match(str(review_str))
    url = m1.group(1)
#    id = m1.group(2)
#    return url, id  
    return url

# %%
def parse(url):
    global next_page
    global counter
   
    urls = []
    url_list = []

    counter = counter + 1

    page = requests.get(url, params = {"limit": 1000, "offset": 0})
    soup = BeautifulSoup(page.text, "lxml")


#- Extract Review URLs from page(url)
    parent1 = soup.find_all("div", attrs = {"class":"reviewSelector   track_back"})
    parent2 = soup.find_all("div", attrs = {"class":"reviewSelector  "})
    
    for k in parent1: urls.append(k.find("div", attrs = {"class":"wrap"}).div.a.get("href"))
    for l in parent2: urls.append(l.find("div", attrs = {"class":"wrap"}).div.a.get("href"))
        
    urls = ["https://www.tripadvisor.com.sg" + x for x in urls]
    
    
#- Get next page URL
    next_page = soup.find("a", attrs = {"class":"nav next rndBtn ui_button primary taLnk"}).get("href")
    next_page = "https://www.tripadvisor.com.sg" + next_page

    
#- For each review get the details
    taReviewData = pd.DataFrame()

    for url in urls:
        review_page = requests.get(url, params = {"limit": 1000, "offset": 0})
        soup_review_page = BeautifulSoup(review_page.text, "lxml")
        
        
        review_id = soup_review_page.find("div", attrs = {"class":"  reviewSelector "}).get("id")
        review_title = soup_review_page.find("div", attrs = {"class":"quote"}).text
        review_text = soup_review_page.find("div", attrs = {"class":"entry"}).text
        
        review_rating = soup_review_page.find("span", attrs = {"class":"rate sprite-rating_s rating_s"}).img.get("alt")
        regex = re.compile(r"(\d+)\s")
        review_rating = regex.match(str(review_rating)).group(1)

        try:
            review_date = soup_review_page.find("span", attrs = {"class":"ratingDate relativeDate"}).get("title")
        except:
            try:
                review_date = soup_review_page.find("span", attrs = {"class":"ratingDate"}).get("content")
            except:
                review_date = "NoReviewDate"
                
        
        visit_date = soup_review_page.find("span", attrs = {"class":"recommend-titleInline noRatings"}).text
        regex = re.compile(r"Visited\s(.*)")
        visit_date = regex.match(str(visit_date)).group(1)
        
        
        try:
            reviewer_country = soup_review_page.find("div", attrs = {"class":"member_info"}).find("div", attrs = {"class":"location"}).text
        except:
            reviewer_country = " NoCity, NoCountry "
        
        regex = re.compile(r"[\s]?(.*)")
        try:
            reviewer_country = regex.match(str(reviewer_country[1:-1])).group(1)
        except:
            reviewer_country = "NoCountry"
            
            

        reviewer_level = soup_review_page.find("div", attrs = {"class":"memberBadging g10n"}).div.div.get("class")[-1]
        regex = re.compile(r"lvl_(.*)")
        try:
            reviewer_level = regex.match(str(reviewer_level)).group(1)
        except:
            reviewer_level = 0

        taReviewData = taReviewData.append(pd.DataFrame({"0review_id":review_id,
                                                         "1review_title":review_title,
                                                         "2review_text":review_text[2:-1],
                                                         "3review_rating":review_rating,
                                                         "4review_date":review_date,
                                                         "5visit_date":visit_date,
                                                         "6reviewer_country":reviewer_country,
                                                         "7reviewer_level":reviewer_level}, index=[0]),
                                                       ignore_index = True)
        
        
    return taReviewData

# %%
df = pd.DataFrame()
counter = 0

df = parse(base_url)


while next_page and counter < 100:
    print(counter)
    print(next_page)
    df = df.append(parse(next_page), ignore_index=True)

df.to_csv("extract1_400_499.csv", header=True, index=False, encoding='utf-8')
# Out:
# 1
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4010-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 2
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4020-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 3
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4030-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 4
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4040-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 5
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4050-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 6
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4060-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 7
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4070-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 8
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4080-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 9
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4090-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 10
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4100-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 11
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4110-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 12
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4120-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 13
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4130-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 14
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4140-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 15
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4150-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 16
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4160-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 17
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4170-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 18
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4180-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 19
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4190-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 20
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4200-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 21
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4210-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 22
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4220-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 23
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4230-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 24
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4240-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 25
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4250-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 26
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4260-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 27
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4270-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 28
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4280-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 29
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4290-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 30
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4300-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 31
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4310-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 32
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4320-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 33
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4330-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 34
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4340-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 35
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4350-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 36
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4360-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 37
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4370-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 38
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4380-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 39
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4390-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 40
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4400-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 41
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4410-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 42
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4420-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 43
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4430-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 44
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4440-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 45
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4450-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 46
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4460-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 47
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4470-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 48
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4480-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 49
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4490-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 50
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4500-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 51
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4510-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 52
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4520-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 53
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4530-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 54
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4540-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 55
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4550-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 56
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4560-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 57
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4570-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 58
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4580-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 59
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4590-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 60
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4600-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 61
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4610-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 62
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4620-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 63
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4630-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 64
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4640-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 65
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4650-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 66
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4660-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 67
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4670-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 68
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4680-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 69
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4690-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 70
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4700-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 71
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4710-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 72
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4720-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 73
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4730-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 74
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4740-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 75
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4750-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 76
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4760-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 77
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4770-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 78
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4780-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 79
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4790-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 80
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4800-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 81
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4810-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 82
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4820-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 83
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4830-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 84
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4840-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 85
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4850-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 86
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4860-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 87
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4870-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 88
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4880-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 89
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4890-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 90
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4900-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 91
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4910-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 92
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4920-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 93
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4930-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 94
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4940-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 95
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4950-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 96
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4960-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 97
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4970-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 98
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4980-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS
# 99
# https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or4990-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS

# %% [markdown]
# ###### Points to check:
#
# As with the links pages, we want to avoid downloading a given page the next time we need to run the notebook.  While we could save the files by hand, as we did before using dill, a checkpointing library like [ediblepickle](https://pypi.python.org/pypi/ediblepickle/1.1.3) can handle this for you.  (Note, though, that you may not want to enable this until you are sure that your function is working.)
#
# You should also keep in mind that HTTP requests fail occasionally, for transient reasons.  You should plan how to detect and react to these failures.   The [retrying module](https://pypi.python.org/pypi/retrying) is one way to deal with this.
#
# NLP:
# * [nltk does part of speech tagging](http://www.nltk.org/book/ch05.html) but it is a little slow.
# * There may also be heuristics that accomplish the same thing.
# * spaCy's [entity recognition](https://spacy.io/docs/usage/entity-recognition) couble be useful here.
# * coreNLP
#
# PageRank:
# A similar way to determine popularity is to look at their
# [pagerank](http://en.wikipedia.org/wiki/PageRank).  Pagerank is used for web ranking and was originally
# [patented](http://patft.uspto.gov/netacgi/nph-Parser?patentnumber=6285999) by Google and is essentially the stationary distribution of a [markov
# chain](http://en.wikipedia.org/wiki/Markov_chain) implied by the social graph.
