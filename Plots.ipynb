# %%
import pandas as pd
import numpy as np
import dill
from datetime import datetime

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import Spectral6
from ipywidgets import *
import requests
import ujson as json

from bokeh.charts import Bar, output_file, show
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend
from bokeh.plotting import reset_output

# %%
output_notebook()  # output bokeh plots in ipynb
TOOLS = "pan, box_zoom, wheel_zoom, reset, save"

reviews = dill.load(open('tareviews_uss.pkd', 'r'))
#reviews.head(10)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4200534d-0f6a-4e24-b3ca-d43c81d1d2cb">Loading BokehJS ...</span>
#     </div>

# %%
reviews_rating_count = reviews.groupby(["5visit_date", "3review_rating"]).size()
ratingtot = reviews.groupby(["5visit_date"]).size()

# %%
rating1 = reviews_rating_count.ix[:,1]
rating1_final = pd.concat([rating1, ratingtot], axis=1).reset_index()
rating1_final.columns = ["visitdate", "count1", "counttot"]
rating1_final.fillna(0, inplace=True)
rating1_final["pct1"] = (rating1_final["count1"] / rating1_final["counttot"])*100

rating2 = reviews_rating_count.ix[:,2]
rating2_final = pd.concat([rating2, ratingtot], axis=1).reset_index()
rating2_final.columns = ["visitdate", "count2", "counttot"]
rating2_final.fillna(0, inplace=True)
rating2_final["pct2"] = (rating2_final["count2"] / rating2_final["counttot"])*100

rating3 = reviews_rating_count.ix[:,3]
rating3_final = pd.concat([rating3, ratingtot], axis=1).reset_index()
rating3_final.columns = ["visitdate", "count3", "counttot"]
rating3_final.fillna(0, inplace=True)
rating3_final["pct3"] = (rating3_final["count3"] / rating3_final["counttot"])*100

rating4 = reviews_rating_count.ix[:,4]
rating4_final = pd.concat([rating4, ratingtot], axis=1).reset_index()
rating4_final.columns = ["visitdate", "count4", "counttot"]
rating4_final.fillna(0, inplace=True)
rating4_final["pct4"] = (rating4_final["count4"] / rating4_final["counttot"])*100

rating5 = reviews_rating_count.ix[:,5]
rating5_final = pd.concat([rating5, ratingtot], axis=1).reset_index()
rating5_final.columns = ["visitdate", "count5", "counttot"]
rating5_final.fillna(0, inplace=True)
rating5_final["pct5"] = (rating5_final["count5"] / rating5_final["counttot"])*100

# %%
rating_final_pct = pd.concat([rating1_final[["visitdate", "pct1"]], 
                          rating2_final["pct2"],
                          rating3_final["pct3"],
                          rating4_final["pct4"],
                          rating5_final["pct5"]], axis=1)



#-required for sorting
rating_final_pct["month"] = rating_final_pct["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").month)
rating_final_pct["year"] = rating_final_pct["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").year)

#-Delete 2014 records
rating_final_pct = rating_final_pct[rating_final_pct["year"] > 2014]

#-Sort
rating_final_pct = rating_final_pct.sort(['year', 'month'], ascending=[1, 1])

#-Reset index after sorting required for graph
rating_final_pct = rating_final_pct.reset_index(drop=True)

#-Rename Columns
rating_final_pct.columns = ["visitdate", "Terrible", "Poor", "Average", "Very Good", "Excellent", "month", "year"]

rating_final_pct
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel/__main__.py:17: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#          visitdate  Terrible      Poor    Average  Very Good  Excellent  \
# 0     January 2015  0.000000  3.448276  10.344828  29.310345  56.896552
# 1    February 2015  0.000000  0.000000   4.166667  43.750000  52.083333
# 2       March 2015  0.000000  1.754386   5.263158  24.561404  68.421053
# 3       April 2015  1.408451  4.225352   1.408451  35.211268  57.746479
# 4         May 2015  0.000000  1.851852   4.938272  33.333333  59.876543
# 5        June 2015  0.858369  1.716738   5.579399  25.321888  66.523605
# 6        July 2015  2.464789  3.873239  11.267606  38.028169  44.366197
# 7      August 2015  3.053435  1.908397  12.595420  28.244275  54.198473
# 8   September 2015  1.388889  2.314815   7.870370  31.481481  56.944444
# 9     October 2015  1.345291  3.587444   6.278027  30.044843  58.744395
# ...

# %%
rating_final_count = pd.concat([rating1_final[["visitdate", "count1"]], 
                          rating2_final["count2"],
                          rating3_final["count3"],
                          rating4_final["count4"],
                          rating5_final["count5"]], axis=1)

#-required for sorting
rating_final_count["month"] = rating_final_count["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").month)
rating_final_count["year"] = rating_final_count["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").year)

#-Delete 2014 records
rating_final_count = rating_final_count[rating_final_count["year"] > 2014]

#-Sort
rating_final_count = rating_final_count.sort(['year', 'month'], ascending=[1, 1])

#-Reset index after sorting required for graph
rating_final_count = rating_final_count.reset_index(drop=True)

#-Rename Columns
rating_final_count.columns = ["visitdate", "Terrible", "Poor", "Average", "Very Good", "Excellent", "month", "year"]

rating_final_count.head(5)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel/__main__.py:15: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#        visitdate  Terrible  Poor  Average  Very Good  Excellent  month  year
# 0   January 2015       0.0   2.0      6.0         17         33      1  2015
# 1  February 2015       0.0   0.0      2.0         21         25      2  2015
# 2     March 2015       0.0   1.0      3.0         14         39      3  2015
# 3     April 2015       1.0   3.0      1.0         25         41      4  2015
# 4       May 2015       0.0   3.0      8.0         54         97      5  2015

# %%
#import datetime

#today = datetime.date.today()
#first = today.replace(day=1)
#lastMonth = first - datetime.timedelta(days=1)
#filterDate = lastMonth - datetime.timedelta(6*365/12)
#filterDate_Year = filterDate.year
#filterDate_Year

# %%
rating_final_count[-13:-1]
# Out:
#          visitdate  Terrible  Poor  Average  Very Good  Excellent  month  year
# 15      April 2016       1.0   5.0     17.0         76        140      4  2016
# 16        May 2016       2.0   5.0     15.0         68        112      5  2016
# 17       June 2016       5.0   1.0     23.0         58         93      6  2016
# 18       July 2016      14.0  13.0     26.0         97        129      7  2016
# 19     August 2016       6.0   4.0     26.0         74        106      8  2016
# 20  September 2016       1.0   3.0     12.0         54        106      9  2016
# 21    October 2016       2.0   2.0     12.0         52        103     10  2016
# 22   November 2016       1.0   2.0     11.0         38         81     11  2016
# 23   December 2016       5.0   4.0     13.0         74         99     12  2016
# 24    January 2017       2.0   3.0     18.0         40         66      1  2017
# 25   February 2017       3.0   1.0      4.0         41         48      2  2017
# ...

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="06fe9f07-20b6-4779-ad4d-ae5216b3a9ff">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.layouts import column
from bokeh.models import *
from bokeh.plotting import Figure, output_file, show
from bokeh.io import output_notebook, reset_output
from random import random
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider, Select
from bokeh.plotting import Figure, output_file, show


bar = Bar(rating_final_count,
      values = blend("Terrible", "Poor", "Average", "Very Good", "Excellent", name='ratings', labels_name='rating'),
      label = cat(columns='visitdate', sort=False),
      stack = cat(columns='rating', sort=False),
      color = color(columns='rating', palette=["Red", "OrangeRed", "Gold", "LimeGreen", "ForestGreen"], sort=False),
      legend = 'top_right',
      title = "Universal Studios Singapore, Total Reviews",
      tooltips = [('rating', '@rating'), ('Month', '@visitdate')],
         width = 400, height = 400)

show(bar)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bffb3230-0c0e-4b9c-8003-123475305567"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
def update(col= "6-Months"):
    if col == "3-Months":
        bar = Bar(rating_final_count[-4:-1],
              values = blend("Terrible", "Poor", "Average", "Very Good", "Excellent", name='ratings', labels_name='rating'),
              label = cat(columns='visitdate', sort=False),
              stack = cat(columns='rating', sort=False),
              color = color(columns='rating', palette=["Red", "OrangeRed", "Gold", "LimeGreen", "ForestGreen"], sort=False),
              legend = 'top_right',
              title = "Universal Studios Singapore, Total Reviews",
              tooltips = [('rating', '@rating'), ('country', '@visitdate')])
    elif col == "6-Months":
        bar = Bar(rating_final_count[-7:-1],
              values = blend("Terrible", "Poor", "Average", "Very Good", "Excellent", name='ratings', labels_name='rating'),
              label = cat(columns='visitdate', sort=False),
              stack = cat(columns='rating', sort=False),
              color = color(columns='rating', palette=["Red", "OrangeRed", "Gold", "LimeGreen", "ForestGreen"], sort=False),
              legend = 'top_right',
              title = "Universal Studios Singapore, Total Reviews",
              tooltips = [('rating', '@rating'), ('country', '@visitdate')])        
    elif col == "12-Months":
        bar = Bar(rating_final_count[-13:-1],
              values = blend("Terrible", "Poor", "Average", "Very Good", "Excellent", name='ratings', labels_name='rating'),
              label = cat(columns='visitdate', sort=False),
              stack = cat(columns='rating', sort=False),
              color = color(columns='rating', palette=["Red", "OrangeRed", "Gold", "LimeGreen", "ForestGreen"], sort=False),
              legend = 'top_right',
              title = "Universal Studios Singapore, Total Reviews",
              tooltips = [('rating', '@rating'), ('country', '@visitdate')])    
    else:
        bar = Bar(rating_final_count,
              values = blend("Terrible", "Poor", "Average", "Very Good", "Excellent", name='ratings', labels_name='rating'),
              label = cat(columns='visitdate', sort=False),
              stack = cat(columns='rating', sort=False),
              color = color(columns='rating', palette=["Red", "OrangeRed", "Gold", "LimeGreen", "ForestGreen"], sort=False),
              legend = 'top_right',
              title = "Universal Studios Singapore, Total Reviews",
              tooltips = [('rating', '@rating'), ('Month', '@visitdate')])
                              

    show(bar)

# %%
    interact(update, col=('All', '3-Months', '6-Months', '12-Months'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a2a511ca-0a6f-40c9-b861-de5cd207597d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
rating_final_pct.head(5)
# Out:
#        visitdate  Terrible      Poor    Average  Very Good  Excellent  month  \
# 0   January 2015  0.000000  3.448276  10.344828  29.310345  56.896552      1
# 1  February 2015  0.000000  0.000000   4.166667  43.750000  52.083333      2
# 2     March 2015  0.000000  1.754386   5.263158  24.561404  68.421053      3
# 3     April 2015  1.408451  4.225352   1.408451  35.211268  57.746479      4
# 4       May 2015  0.000000  1.851852   4.938272  33.333333  59.876543      5
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
from bokeh.plotting import figure, show

p = figure(plot_width=500, plot_height=500)
p.annular_wedge(x=[2], y=[2], inner_radius=0.75, outer_radius=1,
                start_angle=0, end_angle=3.15, color="green", alpha=0.6)
p.annular_wedge(x=[2], y=[2], inner_radius=0.75, outer_radius=1,
                start_angle=3.15, end_angle=6.3, color="gold", alpha=0.6)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a7e1031b-dc63-4e24-b0b2-ba14bc04eb85"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
from bokeh.plotting import *
from numpy import pi
from bokeh.models import HoverTool

source = ColumnDataSource(
        data=dict(
            percents = [0, 0.05, 0.2, 1],
            percent_100 = [5, 15, 80],
            category = ['Poor ', 'Average ', 'Good '],
            starts = [p*2*pi for p in percents[:-1]],
            ends = [p*2*pi for p in percents[1:]],
            colors = ["red", "yellow", "green"],
        )
    )


hover = HoverTool(
        tooltips=[
            ('category','@category'),
            ('percents','@percent_100%'),
        ]
    )

p = figure(title="Test Plot", tools=[hover], height = 500, width = 500, )

#p.wedge(x=0, y=0, radius=1, start_angle=starts, end_angle=ends, color=colors)
p.annular_wedge(x=0, y=0, inner_radius=0.75, outer_radius=1,
                start_angle=starts, end_angle=ends, color=colors, legend='category', alpha=0.6, source=source)


# display/save everythin  
show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-d0783861b34f> in <module>()
#       8             percent_100 = [5, 15, 80],
#       9             category = ['Poor ', 'Average ', 'Good '],
# ---> 10             starts = [p*2*pi for p in percents[:-1]],
#      11             ends = [p*2*pi for p in percents[1:]],
#      12             colors = ["red", "yellow", "green"],
#
# NameError: name 'percents' is not defined

# %%
rating_final_pct["c_poor"] = rating_final_pct["Terrible"] + rating_final_pct["Poor"]
rating_final_pct["c_good"] = rating_final_pct["Very Good"] + rating_final_pct["Excellent"]
del rating_final_pct["Terrible"]
del rating_final_pct["Poor"]
del rating_final_pct["Very Good"]
del rating_final_pct["Excellent"]
rating_final_pct.head(5)
# Out:
#        visitdate    Average  month  year    c_poor     c_good
# 0   January 2015  10.344828      1  2015  3.448276  86.206897
# 1  February 2015   4.166667      2  2015  0.000000  95.833333
# 2     March 2015   5.263158      3  2015  1.754386  92.982456
# 3     April 2015   1.408451      4  2015  5.633803  92.957746
# 4       May 2015   4.938272      5  2015  1.851852  93.209877

# %%
rating_final_pct[-4:-1]
# Out:
#         visitdate    Average  month  year    c_poor     c_good
# 24   January 2017  13.953488      1  2017  3.875969  82.170543
# 25  February 2017   4.123711      2  2017  4.123711  91.752577
# 26     March 2017  13.541667      3  2017  5.208333  81.250000

# %%
# 3-Months

poor = 0
average = 0
good = 0
for index, row in rating_final_pct[-4:-1].iterrows():  
    poor = (poor + row["c_poor"])
    average = (average + row["Average"])
    good = (good + row["c_good"])
    

new_percents_100 = [round(poor/3, 2), round(average/3, 2), round(good/3, 2)]

new_percents = [0, round(poor/300, 2), round(poor/300 + average/300, 2), round(poor/300 + average/300 + good/300, 2)]

print new_percents
print new_percents_100
# Out:
# [0, 0.04, 0.15, 1.0]
# [4.4, 10.54, 85.06]

# %%
from bokeh.plotting import *
from numpy import pi
from bokeh.models import HoverTool


starts = [p*2*pi for p in percents[:-1]]
ends = [p*2*pi for p in percents[1:]]

source = ColumnDataSource(
        data=dict(
            percents = new_percents,
            percent_100 = new_percents_100,
            category = ['Poor ', 'Average ', 'Good '],
            starts = starts,
            ends = ends,
            colors = ["red", "yellow", "green"],
        )
    )

print [p*2*pi for p in percents[:-1]]
print [p*2*pi for p in percents[1:]]

print starts
print ends

hover = HoverTool(
        tooltips=[
            ('category','@category'),
            ('percents','@percent_100%'),
        ]
    )

plot = figure(title="Real Values", tools=[hover], height = 500, width = 500, )

#p.wedge(x=0, y=0, radius=1, start_angle=starts, end_angle=ends, color=colors)
plot.annular_wedge(x=0, y=0, inner_radius=0.75, outer_radius=1,
                start_angle=starts, end_angle=ends, color=colors, legend='category', alpha=0.6, source=source)

show(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-9a99858759ae> in <module>()
#       4
#       5
# ----> 6 starts = [p*2*pi for p in percents[:-1]]
#       7 ends = [p*2*pi for p in percents[1:]]
#       8
#
# NameError: name 'percents' is not defined

# %%
source.data['percents']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-3fb4c47e04ae> in <module>()
# ----> 1 source.data['percents']
#
# NameError: name 'source' is not defined

# %%
starts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-fe679966c855> in <module>()
# ----> 1 starts
#
# NameError: name 'starts' is not defined

# %%
ends
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-6a852b6526d3> in <module>()
# ----> 1 ends
#
# NameError: name 'ends' is not defined

# %% [markdown]
# # Compare Plot

# %%
reviews_gbb = dill.load(open('tareviews_gbb.pkd', 'r'))

# %%
rating1_gbb = reviews_rating_count_gbb.ix[:,1]
rating1_final_gbb = pd.concat([rating1_gbb, ratingtot_gbb], axis=1).reset_index()
rating1_final_gbb.columns = ["visitdate", "count1", "counttot"]
rating1_final_gbb.fillna(0, inplace=True)
rating1_final_gbb["pct1"] = (rating1_final_gbb["count1"] / rating1_final_gbb["counttot"])*100

rating2_gbb = reviews_rating_count_gbb.ix[:,2]
rating2_final_gbb = pd.concat([rating2_gbb, ratingtot_gbb], axis=1).reset_index()
rating2_final_gbb.columns = ["visitdate", "count2", "counttot"]
rating2_final_gbb.fillna(0, inplace=True)
rating2_final_gbb["pct2"] = (rating2_final_gbb["count2"] / rating2_final_gbb["counttot"])*100

rating3_gbb = reviews_rating_count_gbb.ix[:,3]
rating3_final_gbb = pd.concat([rating3_gbb, ratingtot_gbb], axis=1).reset_index()
rating3_final_gbb.columns = ["visitdate", "count3", "counttot"]
rating3_final_gbb.fillna(0, inplace=True)
rating3_final_gbb["pct3"] = (rating3_final_gbb["count3"] / rating3_final_gbb["counttot"])*100

rating4_gbb = reviews_rating_count_gbb.ix[:,4]
rating4_final_gbb = pd.concat([rating4_gbb, ratingtot_gbb], axis=1).reset_index()
rating4_final_gbb.columns = ["visitdate", "count4", "counttot"]
rating4_final_gbb.fillna(0, inplace=True)
rating4_final_gbb["pct4"] = (rating4_final_gbb["count4"] / rating4_final_gbb["counttot"])*100

rating5_gbb = reviews_rating_count_gbb.ix[:,5]
rating5_final_gbb = pd.concat([rating5_gbb, ratingtot_gbb], axis=1).reset_index()
rating5_final_gbb.columns = ["visitdate", "count5", "counttot"]
rating5_final_gbb.fillna(0, inplace=True)
rating5_final_gbb["pct5"] = (rating5_final_gbb["count5"] / rating5_final_gbb["counttot"])*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b747fe8faad3> in <module>()
# ----> 1 rating1_gbb = reviews_rating_count_gbb.ix[:,1]
#       2 rating1_final_gbb = pd.concat([rating1_gbb, ratingtot_gbb], axis=1).reset_index()
#       3 rating1_final_gbb.columns = ["visitdate", "count1", "counttot"]
#       4 rating1_final_gbb.fillna(0, inplace=True)
#       5 rating1_final_gbb["pct1"] = (rating1_final_gbb["count1"] / rating1_final_gbb["counttot"])*100
#
# NameError: name 'reviews_rating_count_gbb' is not defined

# %%
rating_final_count_gbb = pd.concat([rating1_final_gbb[["visitdate", "count1"]], 
                          rating2_final_gbb["count2"],
                          rating3_final_gbb["count3"],
                          rating4_final_gbb["count4"],
                          rating5_final_gbb["count5"]], axis=1)

#-required for sorting
rating_final_count_gbb["month"] = rating_final_count_gbb["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").month)
rating_final_count_gbb["year"] = rating_final_count_gbb["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").year)

#-Delete 2014 records
rating_final_count_gbb = rating_final_count_gbb[rating_final_count_gbb["year"] > 2014]

#-Sort
rating_final_count_gbb = rating_final_count_gbb.sort(['year', 'month'], ascending=[1, 1])

#-Reset index after sorting required for graph
rating_final_count_gbb = rating_final_count_gbb.reset_index(drop=True)

#-Rename Columns
rating_final_count_gbb.columns = ["visitdate", "Terrible", "Poor", "Average", "Very Good", "Excellent", "month", "year"]

rating_final_count_gbb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-fced6afac618> in <module>()
# ----> 1 rating_final_count_gbb = pd.concat([rating1_final_gbb[["visitdate", "count1"]],
#       2                           rating2_final_gbb["count2"],
#       3                           rating3_final_gbb["count3"],
#       4                           rating4_final_gbb["count4"],
#       5                           rating5_final_gbb["count5"]], axis=1)
#
# NameError: name 'rating1_final_gbb' is not defined

# %%
rating_final_count_gbb["total"] = rating_final_count_gbb["Terrible"] + rating_final_count_gbb["Poor"] + rating_final_count_gbb["Average"] + rating_final_count_gbb["Very Good"] + rating_final_count_gbb["Excellent"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-ea52cc41072a> in <module>()
# ----> 1 rating_final_count_gbb["total"] = rating_final_count_gbb["Terrible"] + rating_final_count_gbb["Poor"] + rating_final_count_gbb["Average"] + rating_final_count_gbb["Very Good"] + rating_final_count_gbb["Excellent"]
#
# NameError: name 'rating_final_count_gbb' is not defined

# %%
rating_final_count_gbb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-fd2ddf1761b5> in <module>()
# ----> 1 rating_final_count_gbb
#
# NameError: name 'rating_final_count_gbb' is not defined

# %%
rating_final_count["total"] = rating_final_count["Terrible"] + rating_final_count["Poor"] + rating_final_count["Average"] + rating_final_count["Very Good"] + rating_final_count["Excellent"]
rating_final_count
# Out:
#          visitdate  Terrible  Poor  Average  Very Good  Excellent  month  \
# 0     January 2015       0.0   2.0      6.0         17         33      1
# 1    February 2015       0.0   0.0      2.0         21         25      2
# 2       March 2015       0.0   1.0      3.0         14         39      3
# 3       April 2015       1.0   3.0      1.0         25         41      4
# 4         May 2015       0.0   3.0      8.0         54         97      5
# 5        June 2015       2.0   4.0     13.0         59        155      6
# 6        July 2015       7.0  11.0     32.0        108        126      7
# 7      August 2015       8.0   5.0     33.0         74        142      8
# 8   September 2015       3.0   5.0     17.0         68        123      9
# 9     October 2015       3.0   8.0     14.0         67        131     10
# 10   November 2015       4.0   6.0     19.0         62        126     11
# 11   December 2015       2.0   4.0     27.0         70        155     12
# ...

# %%
p = figure(x_axis_type="datetime", width=500, height=500)
p.xaxis.axis_label = "Visit Date"
p.xaxis.axis_label_text_color = "blue"
p.yaxis.axis_label = "Review Count"
p.yaxis.axis_label_text_color = "blue" 
p.title = "Comparision of Review Counts"
# Out:
# /opt/conda/lib/python2.7/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning: Setting Plot property 'title' using a string was deprecated in 0.12.0,
#             and will be removed. The title is now an object on Plot (which holds all of it's
#             styling properties). Please use Plot.title.text instead.
#
#             SERVER USERS: If you were using plot.title to have the server update the plot title
#             in a callback, you MUST update to plot.title.text as the title object cannot currently
#             be replaced after initialization.
#
#   warn(message)

# %%
rating_final_count.visitdate = pd.to_datetime(rating_final_count.visitdate)
rating_final_count_gbb.visitdate = pd.to_datetime(rating_final_count_gbb.visitdate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-9fc2c10058ca> in <module>()
#       1 rating_final_count.visitdate = pd.to_datetime(rating_final_count.visitdate)
# ----> 2 rating_final_count_gbb.visitdate = pd.to_datetime(rating_final_count_gbb.visitdate)
#
# NameError: name 'rating_final_count_gbb' is not defined

# %%
p.line(rating_final_count.visitdate, rating_final_count.total, color="red", legend = "USS")
p.line(rating_final_count_gbb.visitdate, rating_final_count_gbb.total, color="blue", legend = "GBB")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-a7a787664048> in <module>()
#       1 p.line(rating_final_count.visitdate, rating_final_count.total, color="red", legend = "USS")
# ----> 2 p.line(rating_final_count_gbb.visitdate, rating_final_count_gbb.total, color="blue", legend = "GBB")
#
# NameError: name 'rating_final_count_gbb' is not defined

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2b753983-3701-4b20-baa7-951e216d247c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
rating_final_pct_gbb = pd.concat([rating1_final_gbb[["visitdate", "pct1"]], 
                          rating2_final_gbb["pct2"],
                          rating3_final_gbb["pct3"],
                          rating4_final_gbb["pct4"],
                          rating5_final_gbb["pct5"]], axis=1)



#-required for sorting
rating_final_pct_gbb["month"] = rating_final_pct_gbb["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").month)
rating_final_pct_gbb["year"] = rating_final_pct_gbb["visitdate"].apply(lambda x: datetime.strptime(x, "%B %Y").year)

#-Delete 2014 records
rating_final_pct_gbb = rating_final_pct_gbb[rating_final_pct_gbb["year"] > 2014]

#-Sort
rating_final_pct_gbb = rating_final_pct_gbb.sort(['year', 'month'], ascending=[1, 1])

#-Reset index after sorting required for graph
rating_final_pct_gbb = rating_final_pct_gbb.reset_index(drop=True)

#-Rename Columns
rating_final_pct_gbb.columns = ["visitdate", "Terrible", "Poor", "Average", "Very Good", "Excellent", "month", "year"]

rating_final_pct_gbb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-04c423dd990c> in <module>()
# ----> 1 rating_final_pct_gbb = pd.concat([rating1_final_gbb[["visitdate", "pct1"]],
#       2                           rating2_final_gbb["pct2"],
#       3                           rating3_final_gbb["pct3"],
#       4                           rating4_final_gbb["pct4"],
#       5                           rating5_final_gbb["pct5"]], axis=1)
#
# NameError: name 'rating1_final_gbb' is not defined

# %%
rating_final_pct_gbb["c_poor"] = rating_final_pct_gbb["Terrible"] + rating_final_pct_gbb["Poor"]
rating_final_pct_gbb["c_good"] = rating_final_pct_gbb["Very Good"] + rating_final_pct_gbb["Excellent"]
del rating_final_pct_gbb["Terrible"]
del rating_final_pct_gbb["Poor"]
del rating_final_pct_gbb["Very Good"]
del rating_final_pct_gbb["Excellent"]
rating_final_pct_gbb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-8ef23c4596cb> in <module>()
# ----> 1 rating_final_pct_gbb["c_poor"] = rating_final_pct_gbb["Terrible"] + rating_final_pct_gbb["Poor"]
#       2 rating_final_pct_gbb["c_good"] = rating_final_pct_gbb["Very Good"] + rating_final_pct_gbb["Excellent"]
#       3 del rating_final_pct_gbb["Terrible"]
#       4 del rating_final_pct_gbb["Poor"]
#       5 del rating_final_pct_gbb["Very Good"]
#
# NameError: name 'rating_final_pct_gbb' is not defined

# %%
rating_final_pct
# Out:
#          visitdate    Average  month  year    c_poor     c_good
# 0     January 2015  10.344828      1  2015  3.448276  86.206897
# 1    February 2015   4.166667      2  2015  0.000000  95.833333
# 2       March 2015   5.263158      3  2015  1.754386  92.982456
# 3       April 2015   1.408451      4  2015  5.633803  92.957746
# 4         May 2015   4.938272      5  2015  1.851852  93.209877
# 5        June 2015   5.579399      6  2015  2.575107  91.845494
# 6        July 2015  11.267606      7  2015  6.338028  82.394366
# 7      August 2015  12.595420      8  2015  4.961832  82.442748
# 8   September 2015   7.870370      9  2015  3.703704  88.425926
# 9     October 2015   6.278027     10  2015  4.932735  88.789238
# 10   November 2015   8.755760     11  2015  4.608295  86.635945
# 11   December 2015  10.465116     12  2015  2.325581  87.209302
# 12    January 2016  11.363636      1  2016  4.090909  84.545455
# 13   February 2016   8.088235      2  2016  0.735294  91.176471
# ...

# %%
from bokeh.sampledata.olympics2014 import data

# %%
from bokeh.charts.utils import df_from_json

# %%
df = df_from_json(data)

# %%
df.head(10)
# Out:
#   abbr  bronze  gold  silver  total        name
# 0  ALB       0     0       0      0     Albania
# 1  AND       0     0       0      0     Andorra
# 2  ARG       0     0       0      0   Argentina
# 3  ARM       0     0       0      0     Armenia
# 4  AUS       1     0       2      3   Australia
# 5  AUT       1     2       6      9     Austria
# 6  AZE       0     0       0      0  Azerbaijan
# 7  BLR       1     5       0      6     Belarus
# 8  BEL       0     0       0      0     Belgium
# 9  BMU       0     0       0      0     Bermuda

# %%
from bokeh.charts import Donut, show, output_file
from bokeh.charts.utils import df_from_json
from bokeh.sampledata.olympics2014 import data

import pandas as pd

# utilize utility to make it easy to get json/dict data converted to a dataframe
df = df_from_json(data)

# filter by countries with at least one medal and sort by total medals
df = df[df['total'] > 8]
df = df.sort_values(by="total", ascending=False)
df = pd.melt(df, id_vars=['abbr'],
             value_vars=['bronze', 'silver', 'gold'],
             value_name='medal_count', var_name='medal')

# original example
d = Donut(df, label=['abbr', 'medal'], values='medal_count',
          text_font_size='8pt', hover_text='medal_count')

show(d)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="73f6e89d-8686-49f0-bfeb-a90a2fbed498"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
data.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-efa692752119> in <module>()
# ----> 1 data.describe()
#
# AttributeError: 'dict' object has no attribute 'describe'

# %%
rating_final_count["total"] = rating_final_count["Terrible"] + rating_final_count["Poor"] + rating_final_count["Average"] + rating_final_count["Very Good"] + rating_final_count["Excellent"]
rating_final_count =
# Out:
#     visitdate  Terrible  Poor  Average  Very Good  Excellent  month  year  \
# 0  2015-01-01       0.0   2.0      6.0         17         33      1  2015
# 1  2015-02-01       0.0   0.0      2.0         21         25      2  2015
# 2  2015-03-01       0.0   1.0      3.0         14         39      3  2015
# 3  2015-04-01       1.0   3.0      1.0         25         41      4  2015
# 4  2015-05-01       0.0   3.0      8.0         54         97      5  2015
# 5  2015-06-01       2.0   4.0     13.0         59        155      6  2015
# 6  2015-07-01       7.0  11.0     32.0        108        126      7  2015
# 7  2015-08-01       8.0   5.0     33.0         74        142      8  2015
# 8  2015-09-01       3.0   5.0     17.0         68        123      9  2015
# 9  2015-10-01       3.0   8.0     14.0         67        131     10  2015
# 10 2015-11-01       4.0   6.0     19.0         62        126     11  2015
# 11 2015-12-01       2.0   4.0     27.0         70        155     12  2015
# ...

# %%
reviews_valid_inter_gbb = reviews_gbb[(reviews_gbb['9country_mod'] != "No Value") & (reviews_gbb['9country_mod'] != "Singapore")]
reviews_valid_inter_top_gbb = reviews_valid_inter_gbb.groupby(["9country_mod"]).size().nlargest(20).reset_index(name='top20')

reviews_valid_inter = reviews[(reviews['9country_mod'] != "No Value") & (reviews['9country_mod'] != "Singapore")]
reviews_valid_inter_top = reviews_valid_inter.groupby(["9country_mod"]).size().nlargest(20).reset_index(name='top20')

# %%
country_reviews_tot = pd.merge(reviews_valid_inter_top_gbb, reviews_valid_inter_top, on='9country_mod', how='outer', suffixes=('_gbb', '_uss'))
country_reviews_tot['total'] = country_reviews_tot['top20_uss'] + country_reviews_tot['top20_gbb']
country_reviews_tot = country_reviews_tot.sort_values(by="total", ascending=False).drop(country_reviews_tot.index[5:])
country_reviews_tot.columns = ['country', 'GBB', 'USS', 'total']
country_reviews_tot
# Out:
#           country     GBB    USS   total
# 0       Australia  3963.0  781.0  4744.0
# 1  United Kingdom  2483.0  266.0  2749.0
# 3           India  1447.0  763.0  2210.0
# 2   United States  1518.0   91.0  1609.0
# 4       Indonesia   511.0  189.0   700.0

# %%
country_reviews_tot = pd.melt(country_reviews_tot, id_vars=['country'],
                              value_vars=['USS', 'GBB'],
                              value_name='review_count', var_name='review')

# original example
d = Donut(country_reviews_tot, label=['country', 'review'], values='review_count',
          text_font_size='8pt', hover_text='review_count')

show(d)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eb35d5fa-bc8a-4495-a475-937824b2334c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
